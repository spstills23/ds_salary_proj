# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head()
# Out:
#                Job Title               Salary Estimate  \
# 0         Data Scientist  $108K-$145K (Glassdoor est.)
# 1         Data Scientist  $108K-$145K (Glassdoor est.)
# 2         Data Scientist  $108K-$145K (Glassdoor est.)
# 3  Senior Data Scientist  $108K-$145K (Glassdoor est.)
# 4         Data Scientist  $108K-$145K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Secure our Nation, Ignite your Future\n\nSumma...     4.1
# 1  Who We Are\n\nWere Americas largest mortgage l...     3.9
# 2  The Senior Data Scientist will build and impro...     3.7
# 3  Benson Hill empowers innovators to develop mor...     3.0
# 4  *Organization and Job ID**\nJob ID: 310781\n\n...     3.8
#
#                                  Company Name         Location  \
# 0                                ManTech\n4.1    Chantilly, VA
# 1                          Quicken Loans\n3.9      Detroit, MI
# 2                               Powertek\n3.7   Washington, DC
# ...

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def senority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr.' in title.lower() or 'lead' in title.lower() or 'principle' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower() or 'junior' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# data scientist    618
# data engineer     143
# analyst           121
# na                 89
# mle                19
# director            5
# manager             5
# Name: job_simp, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(senority)

# %%
df.seniority.value_counts()
# Out:
# na        864
# senior    136
# Name: seniority, dtype: int64

# %%
# Job description length
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      3490
# 1      4376
# 2       400
# 3      5536
# 4      5144
#        ...
# 995    4837
# 996    6482
# 997    9630
# 998    2875
# 999    2135
# Name: desc_len, Length: 1000, dtype: int64

# %%
#Competitor Count
df['num_comp'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)

# %%
df.Competitors
# Out:
# 0                                                     -1
# 1                     Citi, Bank of America, Wells Fargo
# 2                                                     -1
# 3                                                     -1
# 4      Oak Ridge National Laboratory, National Renewa...
#                              ...
# 995                                   UnitedHealth Group
# 996                                                   -1
# 997                                                   -1
# 998                   PubMatic, AppNexus, Index Exchange
# 999                                                   -1
# Name: Competitors, Length: 1000, dtype: object

# %%
#removing the \n from Company txt col
df['company_txt'] = df['company_txt'].apply(lambda x: x.replace('\n', ''))

# %%
df.describe()
# Out:
#             Rating      Founded  hourly  employer_provided   min_salary  \
# count  1000.000000  1000.000000  1000.0             1000.0  1000.000000
# mean      3.618800  1716.385000     0.0                0.0    93.494000
# std       0.999673   674.368176     0.0                0.0    20.047241
# min      -1.000000    -1.000000     0.0                0.0    56.000000
# 25%       3.400000  1939.000000     0.0                0.0    91.000000
# 50%       3.800000  1996.000000     0.0                0.0    91.000000
# 75%       4.100000  2006.000000     0.0                0.0    91.000000
# max       5.000000  2018.000000     0.0                0.0   180.000000
#
#         max_salary  average_salary   same_state          age    python_yn  \
# count  1000.000000     1000.000000  1000.000000  1000.000000  1000.000000
# mean    121.610000      107.552000     0.395000    34.689000     0.707000
# std      24.889866       21.083496     0.489095    45.474765     0.455366
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'company_txt', 'job_state', 'same_state', 'age',
#        'python_yn', 'r_studio_yn', 'spark_yn', 'aws_yn', 'excel_yn',
#        'job_simp', 'seniority', 'desc_len', 'num_comp'],
#       dtype='object')

# %%
df['Rating'].hist()

# %%
df.average_salary.hist()

# %%
df.age.hist()

# %%
df.desc_len.hist()

# %%
df.boxplot(column = ['Rating'])

# %%
#correlation between the continous variables
df[['age', 'average_salary', 'Rating','desc_len']].corr()
# Out:
#                      age  average_salary    Rating  desc_len
# age             1.000000       -0.046604  0.047224  0.148753
# average_salary -0.046604        1.000000 -0.003126 -0.017807
# Rating          0.047224       -0.003126  1.000000 -0.166831
# desc_len        0.148753       -0.017807 -0.166831  1.000000

# %%
sns.heatmap(df[['age', 'average_salary', 'Rating','desc_len','num_comp']].corr(), vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={'shrink': .5},cmap='Blues')

# %%
#look at catagorical now
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'company_txt', 'job_state', 'same_state', 'age',
#        'python_yn', 'r_studio_yn', 'spark_yn', 'aws_yn', 'excel_yn',
#        'job_simp', 'seniority', 'desc_len', 'num_comp'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Headquarters','Size','Type of ownership', 
    'Industry', 'Sector', 'Revenue','Company Name','company_txt','job_state','same_state',
   'python_yn', 'r_studio_yn', 'spark_yn', 'aws_yn', 'excel_yn','job_simp', 'seniority']]

# %%
#explore some of the categorical features with bar plots
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print('graph for %s: total= %d' % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index , y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total= 168
# graph for Headquarters: total= 179
# graph for Size: total= 9
# graph for Type of ownership: total= 12
# graph for Industry: total= 52
# graph for Sector: total= 22
# graph for Revenue: total= 14
# graph for Company Name: total= 327
# graph for company_txt: total= 327
# graph for job_state: total= 46
# graph for same_state: total= 2
# graph for python_yn: total= 2
# graph for r_studio_yn: total= 2
# graph for spark_yn: total= 2
# graph for aws_yn: total= 2
# graph for excel_yn: total= 2
# graph for job_simp: total= 7
# graph for seniority: total= 2

# %%
for i in df_cat[['Location', 'Headquarters','company_txt']]:
    cat_num = df_cat[i].value_counts()[:20]
    print('graph for %s: total= %d' % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index , y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for Location: total= 20
# graph for Headquarters: total= 20
# graph for company_txt: total= 20

# %%
#looking at pivot tables with salary and some other features
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'company_txt', 'job_state', 'same_state', 'age',
#        'python_yn', 'r_studio_yn', 'spark_yn', 'aws_yn', 'excel_yn',
#        'job_simp', 'seniority', 'desc_len', 'num_comp'],
#       dtype='object')

# %%
pd.pivot_table(df, index = 'job_simp', values = 'average_salary')
# Out:
#                 average_salary
# job_simp
# analyst             111.132231
# data engineer       105.363636
# data scientist      106.724110
# director             92.800000
# manager              98.300000
# mle                 122.342105
# na                  110.140449

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

pd.pivot_table(df, index = ['job_simp','seniority'], values = 'average_salary')
# Out:
#                           average_salary
# job_simp       seniority
# analyst        na             110.161458
#                senior         114.860000
# data engineer  na             104.110294
#                senior         129.714286
# data scientist na             106.738434
#                senior         106.580357
# director       na              92.800000
# manager        na             104.625000
#                senior          73.000000
# mle            na             121.055556
#                senior         145.500000
# na             na             111.860465
#                senior         108.532609

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)
pd.pivot_table(df, index = ['job_state', 'job_simp'], values = 'average_salary', aggfunc='count').sort_values('job_state', ascending=False)
# Out:
#                               average_salary
# job_state     job_simp
# VA            data scientist               1
#               data engineer                1
# United States data scientist              39
# Remote        director                     1
#               data scientist               1
# OR            data scientist               2
# NJ            data scientist              20
# NE            data scientist               1
# CA            data scientist               1
#  WV           data scientist               1
#  WI           data scientist               4
#               analyst                      2
#               mle                          1
#               na                          24
#  WA           mle                          1
#               data scientist              31
#               data engineer                2
#  VA           na                           7
#               mle                          1
# ...

# %%
#sort job of data scientist and the job state
pd.pivot_table(df[df.job_simp=='data scientist'], index = ['job_state', 'job_simp'], values = 'average_salary').sort_values('average_salary', ascending=False)
# Out:
#                               average_salary
# job_state     job_simp
# VA            data scientist      190.000000
#  CO           data scientist      150.833333
#  AL           data scientist      145.000000
#  TN           data scientist      143.833333
#  NC           data scientist      128.000000
# OR            data scientist      123.500000
#  NJ           data scientist      119.166667
#  OR           data scientist      119.000000
#  NV           data scientist      119.000000
#  GA           data scientist      118.500000
#  FL           data scientist      118.000000
#  KY           data scientist      117.500000
#  MO           data scientist      111.166667
#  CA           data scientist      110.693396
#  NY           data scientist      110.310000
# CA            data scientist      109.500000
#  MI           data scientist      108.666667
#  MN           data scientist      108.666667
#  VA           data scientist      108.050725
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary',
#        'average_salary', 'company_txt', 'job_state', 'same_state', 'age',
#        'python_yn', 'r_studio_yn', 'spark_yn', 'aws_yn', 'excel_yn',
#        'job_simp', 'seniority', 'desc_len', 'num_comp'],
#       dtype='object')

# %%
#rating, industry, sector, revenu, # of comp, employer provided, python, r, spark, aws, excel, desc length, type of ownership
df_pivot = df[['Rating', 'Industry', 'Sector', 'Revenue','average_salary', 'Competitors', 'num_comp', 'python_yn', 'r_studio_yn', 'spark_yn', 'aws_yn', 'excel_yn','Type of ownership']]

# %%
for i in df_pivot.columns:
    print(i)
    print(pd.pivot_table(df_pivot, index = i, values = 'average_salary').sort_values('average_salary', ascending=False))
# Out:
# Rating
#         average_salary
# Rating
#  1.0        135.500000
#  3.0        129.166667
#  4.6        127.900000
#  2.0        125.750000
#  5.0        117.933333
#  4.8        115.611111
#  3.4        113.406977
#  3.3        111.848485
# -1.0        111.548387
#  4.3        111.218750
#  4.1        111.175000
#  4.2        110.642857
#  4.0        110.446154
#  3.1        109.777778
#  3.7        107.754237
#  4.5        106.842857
#  3.6        106.479167
#  4.7        106.194444
#  3.2        106.042373
#  2.2        106.000000
#  2.3        106.000000
#  3.8        105.858696
#  2.6        105.214286
#  3.5        104.820225
#  3.9        104.388393
#  2.7        104.025000
#  2.4        103.166667
#  4.9        102.772727
#  4.4        101.403846
#  2.9        101.217391
#  2.8         98.825000
#  2.5         90.000000
# Industry
#                                          average_salary
# Industry
# Logistics & Supply Chain                     190.000000
# ...

# %%
#who is looking for more 'python' people
pd.pivot_table(df_pivot, index='Revenue', columns= 'python_yn', values = 'average_salary', aggfunc='count')
# Out:
# python_yn                            0      1
# Revenue
# $1 to $2 billion (USD)             9.0   59.0
# $1 to $5 million (USD)             4.0   12.0
# $10 to $25 million (USD)          10.0   13.0
# $10+ billion (USD)                 8.0   82.0
# $100 to $500 million (USD)        99.0   75.0
# $2 to $5 billion (USD)            10.0   44.0
# $25 to $50 million (USD)           6.0   86.0
# $5 to $10 billion (USD)            2.0   27.0
# $5 to $10 million (USD)            NaN    9.0
# $50 to $100 million (USD)         27.0   13.0
# $500 million to $1 billion (USD)  26.0   69.0
# -1                                 4.0    2.0
# Less than $1 million (USD)         1.0   25.0
# Unknown / Non-Applicable          87.0  191.0

# %%
#make a word cloud of job description to see if any keywords pop up useful
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()
